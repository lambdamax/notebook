# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(100,1)
y= 4 + 3*x + np.random.rand(100,1)

plt.plot(x,y,'o')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x_b=np.c_[np.ones((100,1)),x]
theta_best = np.linalg.inv(x_b.T.dot(x_b)).dot(x_b.T).dot(y)
theta_best
# Out:
# array([[4.4975885 ],
#        [2.99977259]])

# %%
x_b.T.dot(x_b)
# Out:
# array([[100.        ,  51.82942106],
#        [ 51.82942106,  35.2310124 ]])

# %%
a = np.array([[1,2,3],[1,2,3]])
b = np.array([[1,2,3],[1,2,3]])

a*b
# np.dot(a,b)
# Out:
# array([[1, 4, 9],
#        [1, 4, 9]])

# %%
y
# Out:
# array([[4.94667596],
#        [6.95489302],
#        [5.85618628],
#        [4.80554834],
#        [6.28090484],
#        [5.14633413],
#        [7.35447212],
#        [7.4263134 ],
#        [5.44002836],
#        [7.02777186],
#        [6.09059238],
#        [5.75358623],
#        [6.22136059],
#        [6.48242839],
#        [5.20901285],
#        [4.70642464],
#        [7.23689281],
#        [7.24394788],
#        [6.77396889],
#        [4.2825073 ],
#        [6.54008118],
#        [6.20203527],
#        [5.58466277],
#        [4.69900289],
#        [7.13692402],
#        [6.99871575],
#        [6.61670098],
#        [5.41281215],
#        [4.77978531],
#        [4.75911821],
#        [4.7380481 ],
#        [7.11490372],
#        [7.43985107],
#        [4.57996985],
#        [4.93759353],
#        [6.67925687],
#        [6.08361398],
#        [6.54254247],
#        [5.13838625],
#        [6.32395354],
#        [6.99377422],
#        [5.70917099],
#        [6.60448452],
#        [7.15073732],
#        [6.36851297],
#        [4.62398954],
#        [7.12781327],
#        [5.69126878],
#        [7.18899867],
#        [7.48403446],
#        [4.80266019],
#        [5.1634807 ],
#        [7.44532396],
#        [5.23423377],
#        [4.64854626],
#        [4.95387335],
#        [6.44278053],
#        [5.50345222],
#        [6.9811474 ],
#        [5.88867316],
#        [7.04711448],
#        [7.20013397],
#        [7.17199829],
#        [6.49478334],
#        [5.01281079],
#        [6.34446809],
#        [5.13404705],
#        [7.01500473],
#        [6.58500301],
#        [5.23093372],
#        [6.92182603],
#        [6.01209095],
#        [6.49622241],
#        [5.87992767],
#        [6.32769799],
#        [5.51302831],
#        [6.64556107],
#        [6.12742887],
#        [4.68645475],
#        [5.38603323],
#        [4.58910388],
#        [5.22660875],
#        [5.96209388],
#        [5.41964466],
#        [5.64314198],
#        [5.4040899 ],
#        [6.76924213],
#        [7.26590117],
#        [6.75576131],
#        [4.80693919],
#        [6.45626549],
#        [6.22110894],
#        [5.36741124],
#        [7.71857208],
#        [5.67014698],
#        [7.29833431],
#        [5.20668979],
#        [6.83224045],
#        [5.03240267],
#        [6.80229448]])
